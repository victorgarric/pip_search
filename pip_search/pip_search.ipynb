# %%
for package in search('http'):
    print(package)
# Out:
# Package(name='http', version='0.02', released='2012-02-12T01:53:36+0000', description='HTTP library for Python')
# Package(name='http1', version='1.0.2', released='2020-05-10T17:09:42+0000', description='http1 is an API to perform HTTP requests in a single call')
# Package(name='http3', version='0.6.7', released='2019-07-08T14:58:54+0000', description='The next generation HTTP client.')
# Package(name='opensitua-http', version='0.0.72', released='2021-06-29T14:06:00+0000', description='A core functions package')
# Package(name='os-http', version='0.1.0', released='2016-04-11T06:20:41+0000', description='Simple HTTP CLI for OpenStack')
# Package(name='pcap2http', version='1.1', released='2016-05-29T18:08:55+0000', description='Parse pcap file with python and watch sites in a browser or a file system')
# Package(name='progressed-http', version='1.0.0', released='2017-10-08T08:56:39+0000', description='Personal http req/resp handler with origin progress bar support')
# Package(name='pulumi-http', version='0.0.9', released='2024-10-16T18:24:07+0000', description='A Pulumi package for creating and managing HTTP cloud resources.')
# Package(name='pushjack-http2', version='2.1.0', released='2021-02-28T22:34:49+0000', description='Push notifications for APNS (iOS) and GCM (Android)')
# Package(name='pwbus-http', version='0.1.33', released='2021-04-10T11:22:03+0000', description='HTTP Server for PWBUS')
# Package(name='pyodide-http', version='0.2.1', released='2023-03-30T19:38:05+0000', description='Patch requests, urllib and urllib3 to make them work in Pyodide')
# Package(name='on_http', version='1.0.2', released='2016-02-10T20:45:39+0000', description='RackHD API Documentation')
# Package(name='phoopy-http', version='1.0.6', released='2020-07-28T20:35:38+0000', description='Http library for phoopy framework')
# Package(name='py2http', version='0.1.60', released='2024-02-22T11:48:02+0000', description='Declarative HTTP service entry point.')
# Package(name='pypomes-http', version='0.4.8', released='2024-11-25T14:51:59+0000', description='A collection of Python pomes, penyeach (HTTP modules)')
# Package(name='pytest-http', version='0.1.1', released='2024-08-22T09:13:02+0000', description='Fixture "http" for http requests')
# Package(name='pyupdater-http', version='0.7.0', released='2022-11-30T08:39:32+0000', description='PyUpdater Plugin: HTTP upload support')
# Package(name='foyou-http', version='0.0.16', released='2023-04-17T08:55:24+0000', description='simple http server for share files.')
# Package(name='fuwa-http', version='1.0.2a0', released='2022-02-17T10:07:58+0000', description='The http client implementation for the fuwa eco-system')
# Package(name='gufo-http', version='0.3.1', released='2024-06-03T08:56:09+0000', description='None')
# Package(name='hacked-http', version='0.0.1', released='2014-10-09T16:38:58+0000', description='Hacked Urllib2 는 warning.or.kr 같은 방어벽을 뚫는데 목적이 있습니다.')
# Package(name='HammerTime-http', version='0.10.1', released='2024-04-04T18:41:47+0000', description='HammerTime is an HTTP client library aiming to perform a large number of requests on a server as fast as it can take them, but without distrupting operations significantly.')
# Package(name='http2async', version='0.0.dev1624557921', released='2021-06-24T18:05:22+0000', description='Http 2 Async')
# Package(name='http2client', version='0.1.0', released='2022-10-02T03:08:59+0000', description='A simple HTTP/2 client for Cyber Security')
# Package(name='http2json', version='1.0.7', released='2019-12-06T08:01:39+0000', description='http2json')
# Package(name='http2py', version='0.1.29', released='2024-01-16T14:38:36+0000', description='Tools to create python binders to http web services.')
# Package(name='http2rmq', version='0.0.dev1624561359', released='2021-06-24T19:02:41+0000', description='RabbitMQ for http2async')
# Package(name='HTTP4Store', version='0.3.1', released='2010-10-13T18:52:14+0000', description='HTTP4Store - python client for 4Store.org (4s-httpd)')
# Package(name='http-access', version='0.1.3', released='2022-02-11T16:39:02+0000', description='http direct access django app')
# Package(name='http-adapter', version='1.0.0', released='2021-08-31T03:10:08+0000', description='Python Framework.')
# Package(name='http-browser', version='1.1.5', released='2024-08-05T07:26:09+0000', description='http_browser')
# Package(name='http-bruteforce', version='1.0', released='2023-12-09T15:27:48+0000', description='')
# Package(name='http-butler', version='0.4.0', released='2017-02-05T15:37:54+0000', description='Light flask server')
# Package(name='http-caching4', version='0.1.0', released='2021-12-07T20:11:38+0000', description='Caching support for Async httpx Client. Cloned from https://github.com/kovan/httpx-caching, https://github.com/johtso/httpx-caching')
# Package(name='http-utils', version='0.1.4', released='2024-01-18T22:15:10+0000', description='')
# Package(name='http-cmd', version='0.1', released='2014-10-23T07:08:32+0000', description='a library to simplify some simple cmd interaction (http based)')
# Package(name='http-constants', version='0.5.0', released='2020-08-04T20:35:46+0000', description='The set of standard http constants for headers and statuses')
# Package(name='http-containerize', version='0.4.3', released='2021-08-11T15:33:05+0000', description='')
# Package(name='http-copy', version='1.0.1', released='2022-05-21T12:50:13+0000', description="A simple tool to 'copy' local file or directory to a remote url (recursively) through http.")
# Package(name='http-ece', version='1.2.1', released='2024-08-08T00:10:47+0000', description='Encrypted Content Encoding for HTTP')

# %%
def search(
    query: str, opts: Union[dict, Namespace] = {}
) -> Generator[Package, None, None]:
    """Search for packages matching the query

    Yields:
        Package: package object
    """
    snippets = []
    s = requests.Session()
    for page in range(1, config.page_size + 1):
        params = {"q": query, "page": page}
        r = s.get(config.api_url, params=params)
        soup = BeautifulSoup(r.text, "html.parser")
        snippets += soup.select('a[class*="package-snippet"]')
    if "sort" in opts:
        if opts.sort == "name":
            snippets = sorted(
                snippets,
                key=lambda s: s.select_one('span[class*="package-snippet__name"]').text.strip(),
            )
            print(snippets)
            snippets = sorted(
                snippets,
                key=lambda s: parse_version(
                    s.select_one('span[class*="package-snippet__version"]').text.strip()
                ),
            )
            print(snippets)
        elif opts.sort == "version":
            from pkg_resources import parse_version

            snippets = sorted(
                snippets,
                key=lambda s: parse_version(
                    s.select_one('span[class*="package-snippet__version"]').text.strip()
                ),
            )
        elif opts.sort == "released":
            snippets = sorted(
                snippets,
                key=lambda s: s.select_one('span[class*="package-snippet__created"]').find(
                    "time"
                )["datetime"],
            )
    for snippet in snippets:
        link = urljoin(config.api_url, snippet.get("href"))
        package = re.sub(
            r"\s+", " ", snippet.select_one('span[class*="package-snippet__name"]').text.strip()
        )

        response = s.get(link)
        package_page = BeautifulSoup(response.text, "html.parser")
        version_element = package_page.select_one('h1.package-header__name')
        version = version_element.text.split()[-1] if version_element else "Unknown"

        # version = re.sub(
        #     r"\s+",
        #     " ",
        #     snippet.select_one('span[class*="package-snippet__version"]').text.strip(),
        # )
        released = re.sub(
            r"\s+",
            " ",

            snippet.select_one('span[class*="package-snippet__created"]').find("time")[
                "datetime"
            ],
        )
        description = re.sub(
            r"\s+",
            " ",
            snippet.select_one('p[class*="package-snippet__description"]').text.strip(),
        )
        yield Package(package, version, released, description, link)

# %%
import re
from argparse import Namespace
from dataclasses import InitVar, dataclass
from datetime import datetime
from typing import Generator, Union
from urllib.parse import urljoin

import requests
from bs4 import BeautifulSoup


class Config:
    """Configuration class"""

    api_url: str = "https://pypi.org/search/"
    page_size: int = 2
    sort_by: str = "name"
    date_format: str = "%d-%-m-%Y"
    link_defualt_format: str = "https://pypi.org/project/{package.name}"


config = Config()


@dataclass
class Package:
    """Package class"""

    name: str
    version: str
    released: str
    description: str
    link: InitVar[str] = None

    def __post_init__(self, link: str = None):
        self.link = link or config.link_defualt_format.format(package=self)
        self.released_date = datetime.strptime(
            self.released, "%Y-%m-%dT%H:%M:%S%z"
        )

    def released_date_str(self, date_format: str = config.date_format) -> str:
        """Return the released date as a string formatted
        according to date_formate ou Config.date_format (default)

        Returns:
            str: Formatted date string
        """
        return self.released_date.strftime(date_format)
